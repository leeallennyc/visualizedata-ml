# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## read and describe the metadata

# %%
fpn_csv = '/Users/leekuczewski/Desktop/The_New_School/Repos/VisualizeData_MachineLearning/visualizedata-ml/ML_assignment_3/option_2/cluster_images.csv'
data = pd.read_csv(fpn_csv, encoding='ISO-8859-1')

# %%
# get column names
list(data)
# Out:
# ['s_no',
#  'artist',
#  'title',
#  'art_movement',
#  'museum_venue',
#  'country_of_origin',
#  'has_text',
#  'primary_medium',
#  'medium',
#  'work_size',
#  'date',
#  'representation',
#  'representation_semi',
#  'kinetic',
#  'map',
#  'map2',
#  'spatial_dimension',
#  'spatial_dimension2',
#  'pl',
#  'si',
#  'va',
#  'te',
#  'co',
#  'or',
#  'sh',
#  'reflection',
#  'po',
#  'li',
#  'ar',
#  'notes']

# %%
data.head()
# Out:
#    s_no              artist                         title art_movement  \
# 0     2  Giorgio de Chirico  The Uncertainty of the Poet    surrealism
# 1     3    Giovanni Anselmo                     Direction  arte povera
# 2     4        Milton Avery                   Yellow Sky     modernism
# 3     5       Gillian Avery                  Distillation  abstraction
# 4     6   Joseph (Jef) Banc          Pair-Bearing Matrix   abstraction
#
#   museum_venue country_of_origin  has_text primary_medium  \
# 0         Tate             Italy     False       painting
# 1         Tate             Italy     False      sculpture
# 2         Tate           America     False       painting
# 3         Tate                UK     False       painting
# 4         Tate            France     False       painting
#
#                                         medium          work_size  ... va  te  \
# 0                      painting, oil on canvas        106 x 94 cm  ...  3   0
# 1             sculpture, fabric, glass & metal  24 x 420 x 335 cm  ...  1   3
# 2                      painting, oil on canvas       156 x 184 cm  ...  2   4
# 3  painting, oil, household paint on hardboard       213 x 152 cm  ...  1   2
# 4              painting, mixed media on canvas         73 x 60 cm  ...  1   4
#
#    co  or  sh  reflection  po  li  ar  \
# 0   0   4   3       False   0   0   5
# 1   0   3   2       False   0   0   5
# 2   4   2   4       False   0   0   5
# 3   0   2   4       False   0   0   5
# 4   1   0   4       False   0   0   5
#
#                                                notes
# 0  distorted perspective, shadow, signification o...
# 1  hard to understand the viewpoint, sense of for...
# 2  flatish, textured shapes & specific colors-lin...
# 3  shapes, layers, paint handlng/texture, orienta...
# 4  ambiguity through abstraction, odd shape, v te...
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Transform datatype

# %%
# Transform the data type values of 'reflection' and 'has_text' from bool True/False to to int64 '0', or '1' 

# Find the data type of Reflection Column
reflection_is_bool = type(data.reflection[0])
has_text_is_bool = type(data.has_text[0])

# Convert to'int64'
data.reflection = data.reflection.astype('int64')
data.has_text = data.has_text.astype('int64')

# Find data type after casting
reflection_after = type(data.reflection[0])
has_text_after = type(data.has_text[0])


# Print new data type of 'reflection'
reflection_after
has_text_after
# Out:
# numpy.int64

# %% [markdown]
# ### Convert  data type in Featured Columns

# %%
# Convert the "reflection" and "has_text" colums from True/False to 0,1
data['reflection'] = data['reflection'].astype(int)
data['has_text'] = data['has_text'].astype(int)

# %% [markdown]
# ### View Data Type Transformation

# %%
data.head(15)
#  In this case we are looking at 'reflection'
# Out:
#     s_no                 artist                                title  \
# 0      2     Giorgio de Chirico         The Uncertainty of the Poet
# 1      3       Giovanni Anselmo                            Direction
# 2      4           Milton Avery                          Yellow Sky
# 3      5          Gillian Avery                         Distillation
# 4      6      Joseph (Jef) Banc                 Pair-Bearing Matrix
# 5      7           Fiona Banner                         Break Point
# 6      8  Thomas Barker of Bath  The Woodman and his Dog in a Storm
# 7      9              Uta Barth                           Field #20
# 8     10       Willi Baumeister        Untitled (Suspended Lines I)
# 9     11             Larry Bell                            Untitled
# 10    12           Hans Bellmer                            The Doll
# 11    13     FrÌ©dÌ©ric Benrath                             Untitled
# 12    14            Jyoti Bhatt                              Baroda
# 13    15     Richard Billingham                               Arrow
# 14    16    Rut Blees Luxemburg                     Viewing the Open
#
#       art_movement museum_venue country_of_origin  has_text primary_medium  \
# 0       surrealism         Tate             Italy         0       painting
# 1      arte povera         Tate             Italy         0      sculpture
# 2        modernism         Tate           America         0       painting
# 3      abstraction         Tate                UK         0       painting
# 4      abstraction         Tate            France         0       painting
# 5       conceptual         Tate                UK         1       painting
# 6   representation         Tate                UK         0       painting
# 7       conceptual         Tate           Germany         0    photography
# 8      abstraction         Tate           Germany         0          print
# 9      postminimal         Tate     United States         0   installation
# 10      surrealism         Tate           Germany         0    photography
# 11     abstraction         Tate            France         0          print
# 12       modernism         Tate             India         0    photography
# 13  representation         Tate                UK         0    photography
# 14      conceptual         Tate           Germany         0    photography
#
#                                          medium           work_size  ... va  \
# 0                       painting, oil on canvas         106 x 94 cm  ...  3
# 1              sculpture, fabric, glass & metal   24 x 420 x 335 cm  ...  1
# 2                       painting, oil on canvas        156 x 184 cm  ...  2
# 3   painting, oil, household paint on hardboard        213 x 152 cm  ...  1
# 4               painting, mixed media on canvas          73 x 60 cm  ...  1
# 5       painting, marker pen, acrylic on canvas    274 x 427 x 6 cm  ...  1
# 6                       painting, oil on canvas        236 x 149 cm  ...  4
# 7     photo, digital print w/ acrylic on canvas        346 x 416 cm  ...  1
# 8                    print, lithograph on paper          26 x 21 cm  ...  1
# 9          installation,sculpture, coated glass  188 x 549 x 244 cm  ...  5
# 10         photo, gelatin silver print on paper          24 x 24 cm  ...  3
# 11                   print, lithograph on paper          43 x 29 cm  ...  3
# 12         photo, gelatin silver print on paper          24 x 61 cm  ...  4
# 13            photo, chromogenic print on paper          51 x 76 cm  ...  2
# 14          photo, paper mounted onto aluminium        150 x 242 cm  ...  4
#
#     te  co  or  sh  reflection  po  li  ar  \
# 0    0   0   4   3           0   0   0   5
# 1    3   0   3   2           0   0   0   5
# 2    4   4   2   4           0   0   0   5
# 3    2   0   2   4           0   0   0   5
# 4    4   1   0   4           0   0   0   5
# 5    2   0   0   0           0   0   5   0
# 6    1   0   4   1           0   0   0   5
# 7    5   0   0   1           0   0   0   5
# 8    1   0   4   3           0   0   5   0
# 9    3   0   0   1           1   0   0   5
# 10   1   0   4   4           0   0   0   0
# 11   5   0   1   1           0   0   5   3
# 12   0   0   1   2           0   0   0   5
# 13   5   1   1   0           0   0   0   5
# 14   2   4   0   1           0   0   0   5
#
#                                                 notes
# 0   distorted perspective, shadow, signification o...
# 1   hard to understand the viewpoint, sense of for...
# 2   flatish, textured shapes & specific colors-lin...
# 3   shapes, layers, paint handlng/texture, orienta...
# 4   ambiguity through abstraction, odd shape, v te...
# 5   ambiguity to do with reading text: placement o...
# 6   dark values, both pairs of eyes fixed on objec...
# 7   v pixelated, very, very large photo; texture:p...
# 8   lines don't meet, orientation of lines creates...
# 9   coating on glass greater at base, fragility of...
# 10  viewpoint looking up at doll w/ no arms, legs ...
# 11  visceral, overlapping scratched, textural line...
# 12  2 images, angled light, strong contrast making...
# 13  slightly pixelated, partially out of focus flo...
# 14  depiction of empty space at night w/ eerie, od...
#
# [15 rows x 30 columns]

# %% [markdown]
# ## create a subset of the columns you will use to fit KMeans
#
# Here, I am **arbitrarily** choosing the seven [visual variables defined by Bertin](https://infovis-wiki.net/wiki/Visual_Variables). Variable descriptions [here](https://github.com/visualizedata/ml/blob/master/ML_assignment_3/option_2/contents-of-cluster_images.csv).
#
# You should choose the columns that you decide will best define the clusters. You may need to make transformations on existing variables.

# %%
X = data[['pl', 'si', 'va', 'te', 'co', 'or', 'reflection', 'has_text']]

# %%
X.head(15)
# Out:
#     pl  si  va  te  co  or  reflection  has_text
# 0    2   2   3   0   0   4           0         0
# 1    4   3   1   3   0   3           0         0
# 2    3   0   2   4   4   2           0         0
# 3    4   3   1   2   0   2           0         0
# 4    1   0   1   4   1   0           0         0
# 5    5   3   1   2   0   0           0         1
# 6    2   0   4   1   0   4           0         0
# 7    1   0   1   5   0   0           0         0
# 8    3   0   1   1   0   4           0         0
# 9    2   1   5   3   0   0           1         0
# 10   3   0   3   1   0   4           0         0
# 11   3   0   3   5   0   1           0         0
# 12   4   0   4   0   0   1           0         0
# 13   3   1   2   5   1   1           0         0
# 14   2   1   4   2   4   0           0         0

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## plot inertia scores by number of clusters

# %%
# first attempt at fitting K means to view change in Inertia
# class sklearn.cluster.KMeans(n_clusters=8, init='k-means++', n_init=10, max_iter=300, tol=0.0001, precompute_distances='auto', verbose=0, random_state=None, copy_x=True, n_jobs=None, algorithm='auto'

# container to store inertia scores over iterations
distortions = []

# fit KMeans iteratively to begin to assess the appropriate number of clusters
for i in range(15, 19):
    km = KMeans(n_clusters=i)
    km.fit(X)
    distortions.append(km.inertia_)
    
# vizualize change in inertia
plt.plot(range(15, 19), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## create silhouette plots to assess various specifications for `n_clusters` in `KMeans`

# %%
# modify this list to include the numbers of clusters you want to see
# I have *arbitrarily* chosen these values
range_n_clusters = [15, 17, 19]

# %%
# modified from: http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import random

for n_clusters in range_n_clusters:
    # Create a subplot
    fig, (ax1) = plt.subplots(1, 1)
    fig.set_size_inches(9, 17)

    # The silhouette coefficient can range from -1, 1 but in this example all lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 5])

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=10, random_state=337)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        # select a random color for this cluster
        r = lambda: random.randint(0,255)
        color = '#%02X%02X%02X' % (r(),r(),r())
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

    plt.show()
# Out:
# For n_clusters = 15 The average silhouette_score is : 0.2098463321765834
# For n_clusters = 17 The average silhouette_score is : 0.2098463321765834
# For n_clusters = 19 The average silhouette_score is : 0.2098463321765834

# %% [markdown]
# ## final fit
#
# After you have decided which features to include and the number of clusters you want, fit your final KMeans model. I have **arbitrarily** chosen 5.

# %%
# set the number of clusters in the final model
my_n_clusters = 10

# %%
km = KMeans(n_clusters=my_n_clusters)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## look at results
#
# The key to knowing if you have chosen the right features and clusters: looking at the images in each cluster and deciding whether they seem to belong together. You could extend this starter code to display the images in this notebook, or you may decide to use Python to write an html file/files to view the images by cluster.

# %%
from IPython.display import Image, HTML, display

# Continuing to work on displaying images
# from skimage import data, io

for i in range(0, max(km.labels_)+1):
    print(" ")
    print("* * * * * * * * * * * * * * * * * * * * * * * * * * * * * * ")
    print("Images in cluster: " + str(i))
    print("* * * * * * * * * * * * * * * * * * * * * * * * * * * * * * ")
    for j in range(0, len(km.labels_)):
        if km.labels_[j] == i & j<=10:
            print(str(j+2) + '_small.jpg')
            
            
            
#Still unable to display the jpegs.            
# imgsrc = "/Users/leekuczewski/Desktop/The_New_School/Repos/VisualizeData_MachineLearning/visualizedata-ml/ML_assignment_3/option_2/img_small" + str(j+2)+'_small.jpg'
# imshow(HTML('<img src =' + imgsrc + '" alt= "ss"  width ="50" height ="70" display = "inline;">'))


# # Declaring a JS representation
# from IPython.display import Javascript
# js = Javascript('alert("hi")');
# display(js)
# Out:
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 0
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 21_small.jpg
# 32_small.jpg
# 34_small.jpg
# 37_small.jpg
# 38_small.jpg
# 40_small.jpg
# 41_small.jpg
# 42_small.jpg
# 44_small.jpg
# 50_small.jpg
# 58_small.jpg
# 64_small.jpg
# 66_small.jpg
# 79_small.jpg
# 82_small.jpg
# 85_small.jpg
# 86_small.jpg
# 92_small.jpg
# 101_small.jpg
# 102_small.jpg
# 104_small.jpg
# 105_small.jpg
# 106_small.jpg
# 112_small.jpg
# 117_small.jpg
# 118_small.jpg
# 121_small.jpg
# 123_small.jpg
# 127_small.jpg
# 148_small.jpg
# 153_small.jpg
# 161_small.jpg
# 164_small.jpg
# 185_small.jpg
# 186_small.jpg
# 189_small.jpg
# 207_small.jpg
# 209_small.jpg
# 210_small.jpg
# 216_small.jpg
# 222_small.jpg
# 223_small.jpg
# 226_small.jpg
# 232_small.jpg
# 238_small.jpg
# 239_small.jpg
# 247_small.jpg
# 248_small.jpg
# 251_small.jpg
# 253_small.jpg
# 255_small.jpg
# 259_small.jpg
# 263_small.jpg
# 276_small.jpg
# 279_small.jpg
# 300_small.jpg
# 319_small.jpg
# 326_small.jpg
# 328_small.jpg
# 330_small.jpg
# 334_small.jpg
# 346_small.jpg
# 347_small.jpg
# 349_small.jpg
# 351_small.jpg
# 359_small.jpg
# 365_small.jpg
# 389_small.jpg
# 399_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 1
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 32_small.jpg
# 33_small.jpg
# 34_small.jpg
# 38_small.jpg
# 40_small.jpg
# 42_small.jpg
# 44_small.jpg
# 50_small.jpg
# 58_small.jpg
# 64_small.jpg
# 66_small.jpg
# 81_small.jpg
# 82_small.jpg
# 86_small.jpg
# 92_small.jpg
# 102_small.jpg
# 104_small.jpg
# 106_small.jpg
# 112_small.jpg
# 118_small.jpg
# 129_small.jpg
# 145_small.jpg
# 148_small.jpg
# 157_small.jpg
# 164_small.jpg
# 186_small.jpg
# 210_small.jpg
# 216_small.jpg
# 222_small.jpg
# 226_small.jpg
# 232_small.jpg
# 238_small.jpg
# 248_small.jpg
# 276_small.jpg
# 289_small.jpg
# 297_small.jpg
# 300_small.jpg
# 321_small.jpg
# 326_small.jpg
# 328_small.jpg
# 330_small.jpg
# 334_small.jpg
# 346_small.jpg
# 373_small.jpg
# 377_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 2
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 16_small.jpg
# 34_small.jpg
# 38_small.jpg
# 42_small.jpg
# 50_small.jpg
# 58_small.jpg
# 66_small.jpg
# 69_small.jpg
# 79_small.jpg
# 82_small.jpg
# 86_small.jpg
# 88_small.jpg
# 102_small.jpg
# 106_small.jpg
# 118_small.jpg
# 123_small.jpg
# 127_small.jpg
# 169_small.jpg
# 186_small.jpg
# 188_small.jpg
# 192_small.jpg
# 207_small.jpg
# 208_small.jpg
# 210_small.jpg
# 213_small.jpg
# 220_small.jpg
# 222_small.jpg
# 223_small.jpg
# 226_small.jpg
# 238_small.jpg
# 239_small.jpg
# 240_small.jpg
